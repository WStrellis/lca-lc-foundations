# %%
import warnings
warnings.filterwarnings("ignore", message="The default value of `allowed_objects`")

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent
from langchain_openrouter import ChatOpenRouter

model = ChatOpenRouter(
    model="openrouter/owl-alpha",
    temperature=0.5,
)


agent = create_agent(
    model=model
)
# Out:
# /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langgraph/checkpoint/serde/encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Westley and I hiked the Zion Traverse in March.")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Westley and I hiked the Zion Traverse in March.', additional_kwargs={}, response_metadata={}, id='6c215bd9-2332-475c-9fe2-fffcdf2baedf'),
#               AIMessage(content="Hello Westley! That's an awesome accomplishment — the Zion Traverse is a challenging and beautiful hike. How was your experience? Did you have any favorite parts or memorable moments from the trail?", additional_kwargs={}, response_metadata={'model_name': 'openrouter/owl-alpha', 'id': 'gen-1779043436-14OWJ3WrwqfwwzBJZoFL', 'created': 1779043436, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'}, id='lc_run--019e3740-8544-7e13-abc6-021c308aa7a3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 110, 'output_tokens': 41, 'total_tokens': 151, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}})]}

# %%
question = HumanMessage(content="what trail did I hike in March?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='what trail did I hike in March?', additional_kwargs={}, response_metadata={}, id='065f0f5b-ae73-4f92-8553-1e0bf7f918ee'),
#               AIMessage(content="I don't have access to your personal hiking history or any information about trails you've hiked. I'm OWL, and I can only work with information you provide in our conversation. If you tell me which trail you hiked in March, I'd be happy to help with details or facts about that trail!", additional_kwargs={}, response_metadata={'model_name': 'openrouter/owl-alpha', 'id': 'gen-1779043441-ycq8R5hDz0tIvU6iceQA', 'created': 1779043441, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'}, id='lc_run--019e3740-9975-7c53-b828-baadcdfbf2e0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 101, 'output_tokens': 64, 'total_tokens': 165, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Westley and I hiked the Zion Traverse in March.")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config=config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Westley and I hiked the Zion Traverse in March.', additional_kwargs={}, response_metadata={}, id='4de2a3cb-2981-4420-8536-9426298bf0c1'),
#               AIMessage(content="Hello Westley! That's an awesome accomplishment — the Zion Traverse is no joke! How was the experience? Did you do it in one push or break it up over a few days? I'd love to hear about the highlights (and the tough parts too).", additional_kwargs={}, response_metadata={'model_name': 'openrouter/owl-alpha', 'id': 'gen-1779043452-wGNudYi6zFWqrPPDVQhG', 'created': 1779043452, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'}, id='lc_run--019e3740-c4c9-75b3-942f-5abf58b03bf1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 110, 'output_tokens': 56, 'total_tokens': 166, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}})]}

# %%
question = HumanMessage(content="what trail did I hike in March?")

response = agent.invoke(
    {"messages": [question]},
    config=config,  
)

pprint(response.messages[-1].content)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Westley and I hiked the Zion Traverse in March.', additional_kwargs={}, response_metadata={}, id='4de2a3cb-2981-4420-8536-9426298bf0c1'),
#               AIMessage(content="Hello Westley! That's an awesome accomplishment — the Zion Traverse is no joke! How was the experience? Did you do it in one push or break it up over a few days? I'd love to hear about the highlights (and the tough parts too).", additional_kwargs={}, response_metadata={'model_name': 'openrouter/owl-alpha', 'id': 'gen-1779043452-wGNudYi6zFWqrPPDVQhG', 'created': 1779043452, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'}, id='lc_run--019e3740-c4c9-75b3-942f-5abf58b03bf1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 110, 'output_tokens': 56, 'total_tokens': 166, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#               HumanMessage(content='what trail did I hike in March?', additional_kwargs={}, response_metadata={}, id='4523a9f7-bc0d-4201-8288-f8b0c92942eb'),
#               AIMessage(content="You hiked the **Zion Traverse** in March! That's a serious trek — great choice!", additional_kwargs={}, response_metadata={'model_name': 'openrouter/owl-alpha', 'id': 'gen-1779043458-n6smQ31Dtr79MQmsfXZy', 'created': 1779043458, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'}, id='lc_run--019e3740-dc28-7943-a2bb-3a8ef617e9bd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 176, 'output_tokens': 24, 'total_tokens': 200, 'input_token_details': {'cache_creation': 0, 'cache_read': 0}, 'output_token_details': {'reasoning': 0}}),
#               HumanMessage(content='what trail did I hike in March?', additional_kwargs={}, response_metadata={}, id='3a3daaeb-4ed4-45a7-bcc5-c9bf350c219c'),
#               AIMessage(content='The **Zion Traverse**! You mentioned it earlier — and what a trail that is!', additional_kwargs={}, response_metadata={'model_name': 'openrouter/owl-alpha', 'id': 'gen-1779043795-adP2VJPRh9HLmpQQEcIH', 'created': 1779043795, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'}, id='lc_run--019e3746-0361-7c92-8dd2-6aff2af3aa48-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 210, 'output_tokens': 22, 'total_tokens': 232, 'input_token_details': {'cache_creation': 0, 'cache_read': 128}, 'output_token_details': {'reasoning': 0}}),
#               HumanMessage(content='what trail did I hike in March?', additional_kwargs={}, response_metadata={}, id='b4e02cb6-d038-408b-b34f-ad9133f917fc'),
#               AIMessage(content='The **Zion Traverse**! You told me at the start of our conversation that you hiked it in March. Quite the adventure!', additional_kwargs={}, response_metadata={'model_name': 'openrouter/owl-alpha', 'id': 'gen-1779043827-fR4VahzMCzfDcQGnEvOw', 'created': 1779043827, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'}, id='lc_run--019e3746-80a9-7962-846b-409ba2f85f9b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 242, 'output_tokens': 30, 'total_tokens': 272, 'input_token_details': {'cache_creation': 0, 'cache_read': 128}, 'output_token_details': {'reasoning': 0}}),
#               HumanMessage(content='what trail did I hike in March?', additional_kwargs={}, response_metadata={}, id='e921d4eb-668a-46c4-8cbc-0d6a2ec1729a'),
#               AIMessage(content="The **Zion Traverse**! You've mentioned it a few times now — seems like it left quite an impression! Great trail, great month for it!", additional_kwargs={}, response_metadata={'model_name': 'openrouter/owl-alpha', 'id': 'gen-1779043851-lOC6wDCCUicdAR4mBuF6', 'created': 1779043851, 'object': 'chat.completion', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'openrouter'}, id='lc_run--019e3746-deb3-7093-893b-4d0403ce9534-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 282, 'output_tokens': 35, 'total_tokens': 317, 'input_token_details': {'cache_read': 128, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}})]}
