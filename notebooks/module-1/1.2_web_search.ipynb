# %%
import warnings
warnings.filterwarnings("ignore", message="The default value of `allowed_objects`")

# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain_openrouter import ChatOpenRouter

model = ChatOpenRouter(
    model="openrouter/owl-alpha",
    temperature=0.3,
)

agent = create_agent(
    model=model
)
# Out:
# /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langgraph/checkpoint/serde/encrypted.py:5: LangChainPendingDeprecationWarning: The default value of `allowed_objects` will change in a future version. Pass an explicit value (e.g., allowed_objects='messages' or allowed_objects='core') to suppress this warning.
#   from langgraph.checkpoint.serde.jsonplus import JsonPlusSerializer

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="what 2026 world cup games will be hosted in Atlanta, Georgia?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# The 2026 FIFA World Cup will be co-hosted by the United States, Canada, and Mexico. In Atlanta, Georgia, several group stage matches and potentially a Round of 16 match are scheduled to be held at Mercedes-Benz Stadium. The specific game schedule is not yet finalized, but Atlanta is confirmed as one of the host cities.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("what 2026 world cup games will be hosted in Atlanta, Georgia?")
# Out:
# {'query': 'what 2026 world cup games will be hosted in Atlanta, Georgia?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.atlutd.com/news/atlanta-georgia-host-eight-fifa-world-cup-2026-matches-semifinal',
#    'title': 'Atlanta, Georgia to host eight FIFA World Cup 2026™ matches ...',
#    'content': 'Atlanta, Georgia will host a total of eight FIFA World Cup 2026™ matches, including one of the Semifinals, FIFA announced Sunday.',
#    'score': 0.9126935,
#    'raw_content': None},
#   {'url': 'https://fifaworldcup26.hospitality.fifa.com/venues/atlanta',
#    'title': 'Atlanta | FIFA World Cup 2026 Hospitality from On Location',
# ...

# %%
agent = create_agent(
    model=model,
    tools=[web_search]
)

question = HumanMessage(content="what 2026 world cup games will be hosted in Atlanta, Georgia?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='what 2026 world cup games will be hosted in Atlanta, Georgia?', additional_kwargs={}, response_metadata={}, id='0305d091-9588-430f-af0b-616a9403ffdc'),
#  AIMessage(content="I'll help you find information about the 2026 World Cup games that will be hosted in Atlanta, Georgia.", additional_kwargs={}, response_metadata={'model_name': 'openrouter/owl-alpha', 'id': 'gen-1779035653-FtDdzxcLL7PIMdzxDGvI', 'created': 1779035653, 'object': 'chat.completion', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'openrouter'}, id='lc_run--019e36c9-c66c-7781-b512-7e569f544e69-0', tool_calls=[{'name': 'web_search', 'args': {'query': '2026 World Cup games hosted in Atlanta Georgia'}, 'id': '8b7ee4fa-da42-4af3-a8e6-5d6d07e3015e', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 237, 'output_tokens': 50, 'total_tokens': 287, 'input_token_details': {'cache_read': 0, 'cache_creation': 0}, 'output_token_details': {'reasoning': 0}}),
# ...

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r

# %%
print(response['messages'][-1].content)
# Out:
# Based on the search results, Atlanta, Georgia will host **eight FIFA World Cup 2026™ matches**, including one of the **Semifinal matches**. The games will be played at Atlanta Stadium (Mercedes-Benz Stadium).
#
# Here are the specific matches and dates mentioned:
#
# - **June 21, 2026** at 12:00 PM ET
# - **July 1, 2026** at 12:00 PM ET
# - Additional matches involving teams like Cape Verde and Czechia (specific dates not fully detailed in the results)
#
# The complete match schedule includes:
# - Group stage matches
# - Round of 16 matches
# - Quarterfinal matches
# - One Semifinal match
#
# Atlanta is one of the host cities for the 2026 FIFA World Cup, which will be jointly hosted by the United States, Canada, and Mexico. The city's Mercedes-Benz Stadium, home to the Atlanta Falcons (NFL) and Atlanta United FC (MLS), will serve as the venue for these matches.
