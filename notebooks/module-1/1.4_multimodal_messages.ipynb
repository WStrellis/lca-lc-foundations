# %%
import warnings
warnings.filterwarnings("ignore", message="The default value of `allowed_objects`")

# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain_openrouter import ChatOpenRouter

model = ChatOpenRouter(
    model="nvidia/nemotron-3-nano-omni-30b-a3b-reasoning:free",
    temperature=1.0,
)

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# **Capital City: Selene‑Haven**
#
# *Location*
# Nestled in the gently curving basin of the **Mare Tranquillitatis**, Selene‑Haven occupies a plateau rimmed by the towering **Rimae Pythagoras** cliffs. The city’s central dome sits on a basaltic promontory that juts out into the silent, star‑strewn seas of the Moon, giving it panoramic views of Earthrise, the distant Earth, and the glittering horizon of the lunar night.
#
# *Name & Meaning*
# “Selene” is the ancient Greek goddess of the Moon, and “Haven” reflects the city’s role as a refuge and hub for the scattered lunar colonies, research outposts, and commercial ventures that have made the satellite their home. The full name, **Selene‑Haven**, therefore means “the safe harbor of the Moon.”
#
# *Urban Layout*
# - **The Core** – A massive, translucent dome built from a lattice of carbon‑nanotube fibers and regolith‑glass. Inside, a verdant, climate‑controlled park stretches beneath a domed sky, complete with hydroponic gardens, walking trails, and a central plaza named **Goddess Terrace**.
# - **The Ring** – Encircling the Core, a series of concentric rings host the city’s civic and cultural institutions: the **Lunar Council Hall**, the **Mare Museum of History**, the **Artemis Opera House**, and the **Starlight Library**, a repository of off‑world data stored in quantum‑entangled crystals.
# - **The Spires** – Rising from the outer rim are sleek, silver‑sheathed towers that serve as residential habitats, research labs, and inter‑city transport hubs. Their aerodynamic shapes channel the constant micro‑gravity winds, generating supplemental power through kinetic turbines.
# - **The Expanse** – Beyond the ring lies a network of illuminated streets built into the basalt, lit by soft, amber phosphorescent strips that double as energy collectors. Autonomous rovers and mag‑lev pods glide silently, ferrying citizens and goods between districts.
#
# *Key Features*
# - **Regolith Gardens** – Transparent domes filled with nutrient‑rich regolith that support a variety of Earth crops and native lunar flora, providing food security and a calming aesthetic.
# - **The Lunar Archive** – A subterranean vault where the histories of humanity’s first steps on the Moon are stored in holographic chronicles, accessible via neural interfaces.
# - **Earth Observatory** – A massive telescope perched atop the highest spire, constantly tracking Earth’s weather, solar activity, and the delicate dance of the planet‑Moon system, serving both scientific and symbolic purposes.
# - **The Night Bazaar** – An open‑air market that comes alive when the lunar night deepens, offering exotic goods, rare alloys, and cultural artifacts from the colonies of the Solar System.
#
# *Governance*
# Selene‑Haven is overseen by the **Lunar Council**, a body of elected representatives from each of the major lunar jurisdiction zones (the Oceanic, Highland, and Far‑Side colonies). Decisions are made through a blend of direct democracy (via citizen assemblies) and technocratic oversight, ensuring that scientific insight guides policy.
#
# *Culture & Life*
# Life in Selene‑Haven balances the stark beauty of the lunar environment with a vibrant, multicultural community. Festivals celebrate the **First Step** (the anniversary of humanity’s first Moon landing) with fireworks of metallic dust, while the **Harvest Moon** festival showcases the bounty of the regolith farms. Music is often composed of resonant frequencies that travel through the thin atmosphere, creating haunting melodies that echo across the cratered plains.
#
# *Why Selene‑Haven?*
# The city serves as the political, cultural, and scientific heart of lunar settlement—a place where the ambitions of pioneers, the curiosity of scholars, and the daily lives of families converge. It embodies the Moon’s transition from a barren outpost to a thriving world, a beacon of human ingenuity shining against the endless black of space.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon-city.png', 'type': 'image/png', 'size': 10197213, 'content': <memory at 0x71ddc4230c40>, 'last_modified': datetime.datetime(2026, 5, 17, 19, 12, 10, 230000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Based on the image provided,this is a **futuristic capital city located on the surface of the Moon**.
#
# Here are the key details about this settlement:
#
# *   **Location & Environment:** The city is constructed directly onto the grey, cratered, and barren lunar landscape. In the background, the massive planet Earth hangs in the black, starry sky, indicating this is a colony or base orbiting our home world.
# *   **Urban Core:** The central area features a dense cluster of towering skyscrapers with illuminated windows, representing a bustling modern metropolis adapted for low-gravity environments.
# *   **Life Support Systems:** To sustain life in the airless environment, the city features several massive, transparent geodesic domes. Inside these domes, lush green vegetation is visible, suggesting they function as agricultural farms or large public parks/gardens.
# *   **Transportation & Infrastructure:**
#     *   **Spaceport:** In the foreground, there is a large complex (labeled "Glen Vib S.S.") that serves as a spaceport or airfield. It has multiple illuminated runways where futuristic shuttlecraft and aircraft are parked.
#     *   **Ground Transport:** The city is connected by elevated highways and monorail tracks that loop around the landscape. You can see cars, buses, and futuristic trains moving along these routes.
# *   **Technology:** The scene is filled with advanced technology, including glowing blue infrastructure lines, futuristic vehicles, and what appear to be humanoid figures glowing with energy, suggesting advanced automation or specialized suits.

# %% [markdown]
# ## Audio input

# %%
import base64

from langchain_openrouter import ChatOpenRouter

model = ChatOpenRouter(
    model="mistralai/voxtral-mini-transcribe",
    temperature=0.5,
)

# path to your MP3 file
mp3_path = "/mnt/c/Users/wstre/Music/The_Captain_s_Red_Crest.mp3"  

with open(mp3_path, "rb") as f:
    mp3_bytes = f.read()

aud_b64 = base64.b64encode(mp3_bytes).decode("utf-8")
print("Done.")
# Out:
# Done.

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model,
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/mpeg"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# InternalServerResponseError               Traceback (most recent call last)
# Cell In[13], line 12
#       3 agent = create_agent(
#       4     model=model,
#       5 )
#       7 multimodal_question = HumanMessage(content=[
#       8     {"type": "text", "text": "Tell me about this audio file"},
#       9     {"type": "audio", "base64": aud_b64, "mime_type": "audio/mpeg"}
#      10 ])
# ---> 12 response = agent.invoke(
#      13     {"messages": [multimodal_question]}
#      14 )
#      16 print(response['messages'][-1].content)
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:3094, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3091 chunks: list[dict[str, Any] | Any] = []
#    3092 interrupts: list[Interrupt] = []
# -> 3094 for chunk in self.stream(
#    3095     input,
#    3096     config,
#    3097     context=context,
#    3098     stream_mode=["updates", "values"]
#    3099     if stream_mode == "values"
#    3100     else stream_mode,
#    3101     print_mode=print_mode,
#    3102     output_keys=output_keys,
#    3103     interrupt_before=interrupt_before,
#    3104     interrupt_after=interrupt_after,
#    3105     durability=durability,
#    3106     **kwargs,
#    3107 ):
#    3108     if stream_mode == "values":
#    3109         if len(chunk) == 2:
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langgraph/pregel/main.py:2669, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2667 for task in loop.match_cached_writes():
#    2668     loop.output_writes(task.id, task.writes, cached=True)
# -> 2669 for _ in runner.tick(
#    2670     [t for t in loop.tasks.values() if not t.writes],
#    2671     timeout=self.step_timeout,
#    2672     get_waiter=get_waiter,
#    2673     schedule_task=loop.accept_push,
#    2674 ):
#    2675     # emit output
#    2676     yield from _output(
#    2677         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2678     )
#    2679 loop.after_tick()
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langgraph/pregel/_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langgraph/pregel/_retry.py:71, in run_with_retry(task, retry_policy, configurable)
#      69     task.writes.clear()
#      70     # run the task
# ---> 71     return task.proc.invoke(task.input, config)
#      72 except ParentCommand as exc:
#      73     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langgraph/_internal/_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain/agents/factory.py:1261, in create_agent.<locals>.model_node(state, runtime)
#    1249 request = ModelRequest(
#    1250     model=model,
#    1251     tools=default_tools,
#    (...)   1257     runtime=runtime,
#    1258 )
#    1260 if wrap_model_call_handler is None:
# -> 1261     model_response = _execute_model_sync(request)
#    1262     return _build_commands(model_response)
#    1264 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain/agents/factory.py:1233, in create_agent.<locals>._execute_model_sync(request)
#    1230 if request.system_message:
#    1231     messages = [request.system_message, *messages]
# -> 1233 output = model_.invoke(messages)
#    1234 if name:
#    1235     output.name = name
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:5881, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5874 @override
#    5875 def invoke(
#    5876     self,
#    (...)   5879     **kwargs: Any | None,
#    5880 ) -> Output:
# -> 5881     return self.bound.invoke(
#    5882         input,
#    5883         self._merge_configs(config),
#    5884         **{**self.kwargs, **kwargs},
#    5885     )
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/langchain_openrouter/chat_models.py:510, in ChatOpenRouter._generate(self, messages, stop, run_manager, **kwargs)
#     508 _strip_internal_kwargs(params)
#     509 sdk_messages = _wrap_messages_for_sdk(message_dicts)
# --> 510 response = self.client.chat.send(messages=sdk_messages, **params)
#     511 return self._create_chat_result(response)
#
# File /mnt/c/Users/wstre/projects/lca-lc-foundations/.venv/lib/python3.12/site-packages/openrouter/chat.py:638, in Chat.send(self, messages, http_referer, x_open_router_title, x_open_router_categories, cache_control, debug, frequency_penalty, image_config, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, model, models, parallel_tool_calls, plugins, presence_penalty, provider, reasoning, response_format, seed, service_tier, session_id, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, trace, user, retries, server_url, timeout_ms, http_headers)
#     634     http_res_text = utils.stream_to_text(http_res)
#     635     response_data = unmarshal_json_response(
#     636         errors.InternalServerResponseErrorData, http_res, http_res_text
#     637     )
# --> 638     raise errors.InternalServerResponseError(
#     639         response_data, http_res, http_res_text
#     640     )
#     641 if utils.match_response(http_res, "502", "application/json"):
#     642     http_res_text = utils.stream_to_text(http_res)
#
# InternalServerResponseError: Internal Server Error
# During task with name 'model' and id '0063c4f1-5967-20b0-c148-2442fb474aab'
