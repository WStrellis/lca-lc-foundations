# %%
import warnings
warnings.filterwarnings("ignore", message="The default value of `allowed_objects`")

# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain_openrouter import ChatOpenRouter

agent = create_agent(model=ChatOpenRouter(model="openrouter/owl-alpha"))

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The Moon doesn't have a capital! 🌙
#
# The Moon is a natural satellite of Earth and doesn't have cities, governments, or capitals. It's a celestial body with no permanent human settlements (at least not yet!).
#
# If you're asking about space exploration, the Moon has been visited by astronauts during the Apollo missions, and there are plans for future lunar bases, but as of now, it remains without any "capital" in the traditional sense.
#
# Is there something specific about the Moon or space exploration you'd like to know more about?

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=ChatOpenRouter(model="openrouter/owl-alpha"),
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The city hangs suspended beneath a dome of reinforced silica, a jewel of light against the dark velvet of the void. They call it **Selene Prime**.
#
# From the observation deck of the Spire, the city looks like a circuit board etched into the grey dust. Towers of white carbon-nanotube lattices rise from the crater floor, connected by transit tubes that hum with magnetic levitation trains. The air inside the dome is recycled, crisp and thin, carrying the faint ozone scent of life support systems working overtime.
#
# At the heart of Selene Prime stands the **Lunar Senate**, a structure of flowing water and light, where the gravity is precisely calibrated to Earth-normal to remind the delegates of the home they left behind. Here, the **Governor-General** presides over the Council of Craters, managing the delicate balance between the mining guilds of the far side and the luxury resorts of the near side.
#
# The streets below are paved with sintered regolith, glowing softly underfoot. Holographic advertisements for "Real Earth Gravity" experiences flicker in the plazas. It is a city built on ambition and vacuum, a testament to humanity's refusal to stay grounded.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=ChatOpenRouter(model="openrouter/owl-alpha"),
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunaris

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=ChatOpenRouter(model="openrouter/owl-alpha"),
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
#
# Location: Far side of the Moon, nestled within the Shackleton Crater rim
#
# Vibe: Silent, luminous, and ancient
#
# Economy: Helium-3 mining, deep-space communications relay, and lunar tourism

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=ChatOpenRouter(model="openai/gpt-oss-20b", temperature=1.0),
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of Pluto?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Aureon', location='The southern polar ice cap, beneath the turquoise glow of the seasonal methane auroras', vibe='A lighthouse of civilization in a frozen world', economy='Scientific research & cryogenic harvesting of rare noble gases, hydroponic algae farms, and solar‑thermal fusion modules that power the city’s bioluminescent boulevards')

# %%
response["structured_response"].name
# Out:
# 'Aureon'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Aureon is a city located at The southern polar ice cap, beneath the turquoise glow of the seasonal methane auroras
